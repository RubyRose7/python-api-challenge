# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
print(weather_api_key)
# Out:
# 65d34e92fbec8c11019863b392cefdc6

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
windspeed = []
humidity = []
lat = []
lng = []
max_temp = []
index_counter = 0
set_counter = 1


print("Beginning Data Retrieval")
print("----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# For loop
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        windspeed.append(response["wind"]["speed"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
            
        else:
            index_counter = index_counter + 1
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found.")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 : yarada
# Processing Record 2 of Set 1 : new norfolk
# Processing Record 3 of Set 1 : cape town
# Processing Record 4 of Set 1 : bathsheba
# Processing Record 5 of Set 1 : pevek
# Processing Record 6 of Set 1 : rikitea
# Processing Record 7 of Set 1 : fortuna
# Processing Record 8 of Set 1 : torbay
# Processing Record 9 of Set 1 : san miguel
# Processing Record 10 of Set 1 : marawi
# Processing Record 11 of Set 1 : pochutla
# Processing Record 12 of Set 1 : alice springs
# Processing Record 13 of Set 1 : yumen
# Processing Record 14 of Set 1 : arlit
# Processing Record 15 of Set 1 : dikson
# Processing Record 16 of Set 1 : aswan
# Processing Record 17 of Set 1 : georgetown
# Processing Record 18 of Set 1 : le vauclin
# Processing Record 19 of Set 1 : tezu
# Processing Record 20 of Set 1 : ust-tsilma
# Processing Record 21 of Set 1 : bluff
# City not found. Skipping...
# Processing Record 22 of Set 1 : saint-joseph
# Processing Record 23 of Set 1 : castro
# Processing Record 24 of Set 1 : methven
# City not found. Skipping...
# Processing Record 25 of Set 1 : obala
# Processing Record 26 of Set 1 : turkistan
# Processing Record 27 of Set 1 : avera
# Processing Record 28 of Set 1 : airai
# Processing Record 29 of Set 1 : port alfred
# Processing Record 30 of Set 1 : vaini
# City not found. Skipping...
# Processing Record 31 of Set 1 : opuwo
# Processing Record 32 of Set 1 : lukovetskiy
# Processing Record 33 of Set 1 : altoona
# Processing Record 34 of Set 1 : tuatapere
# Processing Record 35 of Set 1 : butaritari
# Processing Record 36 of Set 1 : saint-philippe
# Processing Record 37 of Set 1 : busselton
# Processing Record 38 of Set 1 : avarua
# City not found. Skipping...
# Processing Record 39 of Set 1 : kaitangata
# Processing Record 40 of Set 1 : deputatskiy
# Processing Record 41 of Set 1 : punta arenas
# Processing Record 42 of Set 1 : mehamn
# City not found. Skipping...
# Processing Record 43 of Set 1 : saldanha
# City not found. Skipping...
# Processing Record 44 of Set 1 : luwuk
# Processing Record 45 of Set 1 : aksarka
# Processing Record 46 of Set 1 : lahij
# Processing Record 47 of Set 1 : qaanaaq
# Processing Record 48 of Set 1 : requena
# City not found. Skipping...
# Processing Record 49 of Set 1 : puerto ayora
# Processing Record 50 of Set 1 : warri
# Processing Record 0 of Set 2 : hermanus
# Processing Record 1 of Set 2 : hobart
# Processing Record 2 of Set 2 : provideniya
# Processing Record 3 of Set 2 : ushuaia
# Processing Record 4 of Set 2 : pacifica
# Processing Record 5 of Set 2 : ilulissat
# Processing Record 6 of Set 2 : la palma
# Processing Record 7 of Set 2 : khatanga
# Processing Record 8 of Set 2 : bredasdorp
# Processing Record 9 of Set 2 : adrar
# Processing Record 10 of Set 2 : peniche
# City not found. Skipping...
# Processing Record 11 of Set 2 : mataura
# Processing Record 12 of Set 2 : oksfjord
# Processing Record 13 of Set 2 : moree
# Processing Record 14 of Set 2 : saint-pierre
# Processing Record 15 of Set 2 : albany
# Processing Record 16 of Set 2 : sabrum
# Processing Record 17 of Set 2 : ojinaga
# Processing Record 18 of Set 2 : chuy
# Processing Record 19 of Set 2 : hilo
# Processing Record 20 of Set 2 : hualmay
# Processing Record 21 of Set 2 : westport
# Processing Record 22 of Set 2 : hamilton
# Processing Record 23 of Set 2 : fort frances
# Processing Record 24 of Set 2 : punganuru
# Processing Record 25 of Set 2 : nagornyy
# Processing Record 26 of Set 2 : esperance
# Processing Record 27 of Set 2 : port elizabeth
# Processing Record 28 of Set 2 : dingle
# Processing Record 29 of Set 2 : poyarkovo
# Processing Record 30 of Set 2 : severo-kurilsk
# Processing Record 31 of Set 2 : drexel heights
# Processing Record 32 of Set 2 : atuona
# Processing Record 33 of Set 2 : culebra
# Processing Record 34 of Set 2 : richards bay
# Processing Record 35 of Set 2 : cidreira
# Processing Record 36 of Set 2 : posadas
# City not found. Skipping...
# Processing Record 37 of Set 2 : thompson
# Processing Record 38 of Set 2 : kapaa
# Processing Record 39 of Set 2 : yellowknife
# Processing Record 40 of Set 2 : broome
# Processing Record 41 of Set 2 : nikolskoye
# Processing Record 42 of Set 2 : martapura
# Processing Record 43 of Set 2 : norman wells
# Processing Record 44 of Set 2 : bari
# Processing Record 45 of Set 2 : margate
# Processing Record 46 of Set 2 : kununurra
# Processing Record 47 of Set 2 : yulara
# City not found. Skipping...
# Processing Record 48 of Set 2 : bakel
# Processing Record 49 of Set 2 : udachnyy
# Processing Record 50 of Set 2 : chicama
# Processing Record 0 of Set 3 : san patricio
# Processing Record 1 of Set 3 : kodiak
# Processing Record 2 of Set 3 : upernavik
# Processing Record 3 of Set 3 : kerman
# Processing Record 4 of Set 3 : san joaquin
# Processing Record 5 of Set 3 : grand-santi
# Processing Record 6 of Set 3 : inhambane
# Processing Record 7 of Set 3 : tiksi
# Processing Record 8 of Set 3 : alofi
# Processing Record 9 of Set 3 : verkh-usugli
# Processing Record 10 of Set 3 : pangnirtung
# Processing Record 11 of Set 3 : cabo san lucas
# Processing Record 12 of Set 3 : lebu
# Processing Record 13 of Set 3 : xinqing
# Processing Record 14 of Set 3 : nguru
# Processing Record 15 of Set 3 : ponta do sol
# Processing Record 16 of Set 3 : arman
# Processing Record 17 of Set 3 : hithadhoo
# Processing Record 18 of Set 3 : bethel
# Processing Record 19 of Set 3 : san marcos
# Processing Record 20 of Set 3 : jamestown
# Processing Record 21 of Set 3 : sao filipe
# Processing Record 22 of Set 3 : east london
# City not found. Skipping...
# Processing Record 23 of Set 3 : caravelas
# Processing Record 24 of Set 3 : chumikan
# Processing Record 25 of Set 3 : mahebourg
# Processing Record 26 of Set 3 : miramar
# Processing Record 27 of Set 3 : mantua
# Processing Record 28 of Set 3 : half moon bay
# Processing Record 29 of Set 3 : matagami
# Processing Record 30 of Set 3 : raciborz
# Processing Record 31 of Set 3 : tuktoyaktuk
# Processing Record 32 of Set 3 : la ronge
# Processing Record 33 of Set 3 : estelle
# Processing Record 34 of Set 3 : dodge city
# Processing Record 35 of Set 3 : thaba-tseka
# Processing Record 36 of Set 3 : katsuura
# Processing Record 37 of Set 3 : hasaki
# Processing Record 38 of Set 3 : vardo
# Processing Record 39 of Set 3 : beringovskiy
# Processing Record 40 of Set 3 : arraial do cabo
# Processing Record 41 of Set 3 : rocha
# Processing Record 42 of Set 3 : san-pedro
# City not found. Skipping...
# Processing Record 43 of Set 3 : barrow
# Processing Record 44 of Set 3 : baihar
# Processing Record 45 of Set 3 : lethbridge
# Processing Record 46 of Set 3 : kinablangan
# Processing Record 47 of Set 3 : berlevag
# Processing Record 48 of Set 3 : krems
# City not found. Skipping...
# Processing Record 49 of Set 3 : husavik
# Processing Record 50 of Set 3 : te anau
# Processing Record 0 of Set 4 : macau
# Processing Record 1 of Set 4 : victoria
# Processing Record 2 of Set 4 : cayenne
# City not found. Skipping...
# Processing Record 3 of Set 4 : tagusao
# Processing Record 4 of Set 4 : marsabit
# Processing Record 5 of Set 4 : baykit
# Processing Record 6 of Set 4 : mejorada del campo
# Processing Record 7 of Set 4 : malokakhovka
# Processing Record 8 of Set 4 : ostrovnoy
# Processing Record 9 of Set 4 : altamira
# Processing Record 10 of Set 4 : vostok
# Processing Record 11 of Set 4 : pombas
# Processing Record 12 of Set 4 : samarai
# Processing Record 13 of Set 4 : kuito
# Processing Record 14 of Set 4 : ixtapa
# Processing Record 15 of Set 4 : laguna
# Processing Record 16 of Set 4 : quatre cocos
# City not found. Skipping...
# Processing Record 17 of Set 4 : jumla
# Processing Record 18 of Set 4 : los llanos de aridane
# Processing Record 19 of Set 4 : geraldton
# Processing Record 20 of Set 4 : sevilla
# Processing Record 21 of Set 4 : fasa
# City not found. Skipping...
# Processing Record 22 of Set 4 : muli
# Processing Record 23 of Set 4 : narsaq
# Processing Record 24 of Set 4 : beloha
# Processing Record 25 of Set 4 : wilkie
# City not found. Skipping...
# Processing Record 26 of Set 4 : leningradskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 : pompeia
# Processing Record 28 of Set 4 : shelopugino
# Processing Record 29 of Set 4 : grande prairie
# Processing Record 30 of Set 4 : sterling
# Processing Record 31 of Set 4 : ballarat
# Processing Record 32 of Set 4 : sioux lookout
# Processing Record 33 of Set 4 : bahia blanca
# Processing Record 34 of Set 4 : binga
# Processing Record 35 of Set 4 : sao jose da coroa grande
# Processing Record 36 of Set 4 : aizawl
# City not found. Skipping...
# Processing Record 37 of Set 4 : vallenar
# Processing Record 38 of Set 4 : daniel flores
# Processing Record 39 of Set 4 : kudahuvadhoo
# Processing Record 40 of Set 4 : puerto escondido
# Processing Record 41 of Set 4 : stornoway
# City not found. Skipping...
# Processing Record 42 of Set 4 : andijon
# Processing Record 43 of Set 4 : ribeira grande
# Processing Record 44 of Set 4 : marion
# Processing Record 45 of Set 4 : pio xii
# Processing Record 46 of Set 4 : sorland
# Processing Record 47 of Set 4 : xining
# Processing Record 48 of Set 4 : hami
# Processing Record 49 of Set 4 : rosetta
# City not found. Skipping...
# Processing Record 50 of Set 4 : boundiali
# Processing Record 0 of Set 5 : sivaki
# Processing Record 1 of Set 5 : alcantara
# Processing Record 2 of Set 5 : saint george
# Processing Record 3 of Set 5 : ajdabiya
# Processing Record 4 of Set 5 : kumano
# Processing Record 5 of Set 5 : freeport
# Processing Record 6 of Set 5 : sandy bay
# Processing Record 7 of Set 5 : mendi
# Processing Record 8 of Set 5 : davila
# Processing Record 9 of Set 5 : carnarvon
# Processing Record 10 of Set 5 : lagoa
# Processing Record 11 of Set 5 : dong hoi
# Processing Record 12 of Set 5 : tommot
# Processing Record 13 of Set 5 : caetite
# Processing Record 14 of Set 5 : bay saint louis
# Processing Record 15 of Set 5 : umm kaddadah
# Processing Record 16 of Set 5 : tual
# Processing Record 17 of Set 5 : pangody
# Processing Record 18 of Set 5 : naushki
# Processing Record 19 of Set 5 : parana
# Processing Record 20 of Set 5 : kiruna
# Processing Record 21 of Set 5 : vung tau
# Processing Record 22 of Set 5 : luau
# Processing Record 23 of Set 5 : coburg
# Processing Record 24 of Set 5 : khani
# Processing Record 25 of Set 5 : luderitz
# Processing Record 26 of Set 5 : podosinovets
# Processing Record 27 of Set 5 : kolokani
# Processing Record 28 of Set 5 : moba
# Processing Record 29 of Set 5 : allonnes
# Processing Record 30 of Set 5 : srednekolymsk
# Processing Record 31 of Set 5 : port lincoln
# Processing Record 32 of Set 5 : monrovia
# Processing Record 33 of Set 5 : todos santos
# Processing Record 34 of Set 5 : vestmannaeyjar
# Processing Record 35 of Set 5 : spremberg
# Processing Record 36 of Set 5 : kahului
# Processing Record 37 of Set 5 : san policarpo
# Processing Record 38 of Set 5 : minab
# Processing Record 39 of Set 5 : darhan
# Processing Record 40 of Set 5 : totness
# Processing Record 41 of Set 5 : sarakhs
# Processing Record 42 of Set 5 : jalu
# Processing Record 43 of Set 5 : huarmey
# Processing Record 44 of Set 5 : tautira
# Processing Record 45 of Set 5 : grindavik
# Processing Record 46 of Set 5 : kabalo
# Processing Record 47 of Set 5 : biak
# Processing Record 48 of Set 5 : yarovoye
# Processing Record 49 of Set 5 : necochea
# Processing Record 50 of Set 5 : san lazaro
# Processing Record 0 of Set 6 : bandarbeyla
# Processing Record 1 of Set 6 : lavrentiya
# Processing Record 2 of Set 6 : santo estevao
# Processing Record 3 of Set 6 : pacific grove
# Processing Record 4 of Set 6 : ciechanow
# Processing Record 5 of Set 6 : praia da vitoria
# Processing Record 6 of Set 6 : mariental
# Processing Record 7 of Set 6 : alta floresta
# Processing Record 8 of Set 6 : stockerau
# Processing Record 9 of Set 6 : aquiraz
# City not found. Skipping...
# Processing Record 10 of Set 6 : asau
# Processing Record 11 of Set 6 : okoritofulpos
# Processing Record 12 of Set 6 : tasiilaq
# Processing Record 13 of Set 6 : turbiv
# City not found. Skipping...
# Processing Record 14 of Set 6 : bacum
# Processing Record 15 of Set 6 : yar-sale
# Processing Record 16 of Set 6 : shubarkuduk
# Processing Record 17 of Set 6 : college
# Processing Record 18 of Set 6 : havre
# Processing Record 19 of Set 6 : barroso
# Processing Record 20 of Set 6 : stary sacz
# Processing Record 21 of Set 6 : corvallis
# Processing Record 22 of Set 6 : boa vista
# City not found. Skipping...
# Processing Record 23 of Set 6 : chokurdakh
# Processing Record 24 of Set 6 : ahipara
# Processing Record 25 of Set 6 : vila franca do campo
# Processing Record 26 of Set 6 : comodoro rivadavia
# Processing Record 27 of Set 6 : ermoupolis
# Processing Record 28 of Set 6 : sistranda
# Processing Record 29 of Set 6 : kimparana
# Processing Record 30 of Set 6 : souillac
# Processing Record 31 of Set 6 : gat
# Processing Record 32 of Set 6 : fare
# City not found. Skipping...
# Processing Record 33 of Set 6 : eyl
# Processing Record 34 of Set 6 : duiwelskloof
# Processing Record 35 of Set 6 : kavaratti
# Processing Record 36 of Set 6 : japura
# Processing Record 37 of Set 6 : tapes
# Processing Record 38 of Set 6 : nouadhibou
# Processing Record 39 of Set 6 : sakakah
# Processing Record 40 of Set 6 : atambua
# Processing Record 41 of Set 6 : hobyo
# Processing Record 42 of Set 6 : kendari
# City not found. Skipping...
# Processing Record 43 of Set 6 : rhyl
# City not found. Skipping...
# Processing Record 44 of Set 6 : mount isa
# Processing Record 45 of Set 6 : constitucion
# Processing Record 46 of Set 6 : meadow lake
# Processing Record 47 of Set 6 : paamiut
# Processing Record 48 of Set 6 : paso de los toros
# Processing Record 49 of Set 6 : waycross
# Processing Record 50 of Set 6 : kavieng
# Processing Record 0 of Set 7 : filingue
# Processing Record 1 of Set 7 : guaymas
# Processing Record 2 of Set 7 : waingapu
# Processing Record 3 of Set 7 : yoichi
# Processing Record 4 of Set 7 : sayyan
# Processing Record 5 of Set 7 : nome
# Processing Record 6 of Set 7 : nishihara
# Processing Record 7 of Set 7 : caluquembe
# Processing Record 8 of Set 7 : longyearbyen
# City not found. Skipping...
# Processing Record 9 of Set 7 : itaituba
# Processing Record 10 of Set 7 : tigzirt
# Processing Record 11 of Set 7 : ketchikan
# Processing Record 12 of Set 7 : shitanjing
# Processing Record 13 of Set 7 : ishikawa
# City not found. Skipping...
# Processing Record 14 of Set 7 : emmett
# Processing Record 15 of Set 7 : mount gambier
# Processing Record 16 of Set 7 : fazilka
# Processing Record 17 of Set 7 : port macquarie
# Processing Record 18 of Set 7 : kruisfontein
# Processing Record 19 of Set 7 : anse-bertrand
# City not found. Skipping...
# Processing Record 20 of Set 7 : santa vitoria do palmar
# Processing Record 21 of Set 7 : jalpa
# Processing Record 22 of Set 7 : guerrero negro
# Processing Record 23 of Set 7 : tura
# Processing Record 24 of Set 7 : genhe
# Processing Record 25 of Set 7 : mandal
# Processing Record 26 of Set 7 : maceio
# Processing Record 27 of Set 7 : ryotsu
# Processing Record 28 of Set 7 : baft
# Processing Record 29 of Set 7 : progreso
# Processing Record 30 of Set 7 : chumphon
# City not found. Skipping...
# Processing Record 31 of Set 7 : grand island
# Processing Record 32 of Set 7 : belmonte
# Processing Record 33 of Set 7 : nanortalik
# Processing Record 34 of Set 7 : balad
# Processing Record 35 of Set 7 : salinas
# Processing Record 36 of Set 7 : mar del plata
# Processing Record 37 of Set 7 : port hardy
# Processing Record 38 of Set 7 : wad rawah
# Processing Record 39 of Set 7 : hovd
# Processing Record 40 of Set 7 : bolshaya glushitsa
# Processing Record 41 of Set 7 : krasnoye-na-volge
# Processing Record 42 of Set 7 : bedford
# Processing Record 43 of Set 7 : namibe
# Processing Record 44 of Set 7 : batticaloa
# Processing Record 45 of Set 7 : bambous virieux
# Processing Record 46 of Set 7 : baoqing
# Processing Record 47 of Set 7 : kisangani
# Processing Record 48 of Set 7 : bodden town
# Processing Record 49 of Set 7 : miles city
# Processing Record 50 of Set 7 : zhezkazgan
# City not found. Skipping...
# Processing Record 0 of Set 8 : gazojak
# Processing Record 1 of Set 8 : fairbanks
# Processing Record 2 of Set 8 : parabel
# Processing Record 3 of Set 8 : sarno
# Processing Record 4 of Set 8 : nizhniy kuranakh
# Processing Record 5 of Set 8 : hornepayne
# Processing Record 6 of Set 8 : lompoc
# Processing Record 7 of Set 8 : yarkovo
# Processing Record 8 of Set 8 : manta
# Processing Record 9 of Set 8 : amahai
# City not found. Skipping...
# Processing Record 10 of Set 8 : nelson bay
# Processing Record 11 of Set 8 : chissamba
# Processing Record 12 of Set 8 : yatou
# Processing Record 13 of Set 8 : bengkulu
# Processing Record 14 of Set 8 : santa isabel do rio negro
# Processing Record 15 of Set 8 : high level
# Processing Record 16 of Set 8 : troitskoye
# Processing Record 17 of Set 8 : mbandaka
# Processing Record 18 of Set 8 : bowen
# Processing Record 19 of Set 8 : cherskiy
# Processing Record 20 of Set 8 : pafos
# Processing Record 21 of Set 8 : hirara
# Processing Record 22 of Set 8 : coahuayana
# Processing Record 23 of Set 8 : guimaraes
# Processing Record 24 of Set 8 : camacupa
# Processing Record 25 of Set 8 : padang
# Processing Record 26 of Set 8 : lukow
# Processing Record 27 of Set 8 : yerbogachen
# Processing Record 28 of Set 8 : namie
# Processing Record 29 of Set 8 : teahupoo
# Processing Record 30 of Set 8 : ambon
# Processing Record 31 of Set 8 : rokytne
# Processing Record 32 of Set 8 : iroquois
# Processing Record 33 of Set 8 : banda aceh
# Processing Record 34 of Set 8 : tobol
# Processing Record 35 of Set 8 : buala
# Processing Record 36 of Set 8 : porto novo
# Processing Record 37 of Set 8 : casino
# Processing Record 38 of Set 8 : hanzhong
# Processing Record 39 of Set 8 : erenhot
# Processing Record 40 of Set 8 : tazovskiy
# Processing Record 41 of Set 8 : vila
# Processing Record 42 of Set 8 : lima
# Processing Record 43 of Set 8 : montepuez
# Processing Record 44 of Set 8 : san jose
# Processing Record 45 of Set 8 : malakal
# Processing Record 46 of Set 8 : komsomolskiy
# Processing Record 47 of Set 8 : salalah
# Processing Record 48 of Set 8 : volkhov
# Processing Record 49 of Set 8 : pajapan
# Processing Record 50 of Set 8 : poso
# Processing Record 0 of Set 9 : hambantota
# Processing Record 1 of Set 9 : portland
# Processing Record 2 of Set 9 : lodeynoye pole
# Processing Record 3 of Set 9 : puteyets
# Processing Record 4 of Set 9 : ancud
# Processing Record 5 of Set 9 : soledar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 9 : naze
# Processing Record 7 of Set 9 : bella vista
# Processing Record 8 of Set 9 : paraiso
# Processing Record 9 of Set 9 : lorengau
# Processing Record 10 of Set 9 : montemarciano
# Processing Record 11 of Set 9 : shelabolikha
# Processing Record 12 of Set 9 : sao gabriel da cachoeira
# Processing Record 13 of Set 9 : puerto madryn
# Processing Record 14 of Set 9 : mahajanga
# Processing Record 15 of Set 9 : port moresby
# Processing Record 16 of Set 9 : shadegan
# Processing Record 17 of Set 9 : magan
# Processing Record 18 of Set 9 : iqaluit
# Processing Record 19 of Set 9 : botou
# Processing Record 20 of Set 9 : bonnyville
# Processing Record 21 of Set 9 : blackwater
# Processing Record 22 of Set 9 : moron
# Processing Record 23 of Set 9 : walvis bay
# City not found. Skipping...
# Processing Record 24 of Set 9 : grand-lahou
# Processing Record 25 of Set 9 : leh
# Processing Record 26 of Set 9 : saskylakh
# Processing Record 27 of Set 9 : maluso
# Processing Record 28 of Set 9 : champerico
# Processing Record 29 of Set 9 : awjilah
# Processing Record 30 of Set 9 : pisco
# Processing Record 31 of Set 9 : raudeberg
# Processing Record 32 of Set 9 : juneau
# Processing Record 33 of Set 9 : karratha
# Processing Record 34 of Set 9 : marsh harbour
# Processing Record 35 of Set 9 : excelsior springs
# Processing Record 36 of Set 9 : pedro ii
# Processing Record 37 of Set 9 : khasan
# Processing Record 38 of Set 9 : aginskoye
# Processing Record 39 of Set 9 : dunedin
# Processing Record 40 of Set 9 : middelburg
# Processing Record 41 of Set 9 : atar
# Processing Record 42 of Set 9 : jiuquan
# Processing Record 43 of Set 9 : beltangadi
# Processing Record 44 of Set 9 : tandil
# Processing Record 45 of Set 9 : aklavik
# Processing Record 46 of Set 9 : corn island
# Processing Record 47 of Set 9 : ta khmau
# Processing Record 48 of Set 9 : oranjemund
# Processing Record 49 of Set 9 : mana
# Processing Record 50 of Set 9 : baruun-urt
# Processing Record 0 of Set 10 : christchurch
# Processing Record 1 of Set 10 : sumbe
# Processing Record 2 of Set 10 : northam
# Processing Record 3 of Set 10 : hofn
# Processing Record 4 of Set 10 : sao joao da barra
# Processing Record 5 of Set 10 : heihe
# City not found. Skipping...
# Processing Record 6 of Set 10 : kindersley
# Processing Record 7 of Set 10 : basco
# City not found. Skipping...
# Processing Record 8 of Set 10 : jiaocheng
# Processing Record 9 of Set 10 : dudinka
# Processing Record 10 of Set 10 : honiara
# Processing Record 11 of Set 10 : rakai
# Processing Record 12 of Set 10 : jardim
# Processing Record 13 of Set 10 : plattsburgh
# Processing Record 14 of Set 10 : pacasmayo
# Processing Record 15 of Set 10 : fengcheng
# Processing Record 16 of Set 10 : blackfoot
# City not found. Skipping...
# Processing Record 17 of Set 10 : goure
# Processing Record 18 of Set 10 : issaquah
# Processing Record 19 of Set 10 : saurimo
# Processing Record 20 of Set 10 : conceicao do araguaia
# Processing Record 21 of Set 10 : marrakesh
# Processing Record 22 of Set 10 : mali
# Processing Record 23 of Set 10 : hampton
# Processing Record 24 of Set 10 : ust-ilimsk
# Processing Record 25 of Set 10 : brive-la-gaillarde
# Processing Record 26 of Set 10 : prabumulih
# Processing Record 27 of Set 10 : songea
# Processing Record 28 of Set 10 : jalingo
# Processing Record 29 of Set 10 : chor
# Processing Record 30 of Set 10 : bac lieu
# Processing Record 31 of Set 10 : bulach
# Processing Record 32 of Set 10 : bartica
# Processing Record 33 of Set 10 : luancheng
# Processing Record 34 of Set 10 : kushiro
# Processing Record 35 of Set 10 : oxelosund
# Processing Record 36 of Set 10 : valparaiso
# Processing Record 37 of Set 10 : uribia
# Processing Record 38 of Set 10 : birao
# Processing Record 39 of Set 10 : diamantino
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 10 : inta
# Processing Record 41 of Set 10 : altay
# Processing Record 42 of Set 10 : nkhata bay
# Processing Record 43 of Set 10 : lusambo
# Processing Record 44 of Set 10 : saint-georges
# Processing Record 45 of Set 10 : rexburg
# Processing Record 46 of Set 10 : gari
# Processing Record 47 of Set 10 : tiznit
# Processing Record 48 of Set 10 : san pedro
# Processing Record 49 of Set 10 : mbaiki
# Processing Record 50 of Set 10 : aykhal
# Processing Record 0 of Set 11 : san cristobal
# Processing Record 1 of Set 11 : digby
# City not found. Skipping...
# Processing Record 2 of Set 11 : calatrava
# Processing Record 3 of Set 11 : loikaw
# Processing Record 4 of Set 11 : vao
# Processing Record 5 of Set 11 : cubulco
# Processing Record 6 of Set 11 : dunmore east
# Processing Record 7 of Set 11 : charters towers
# City not found. Skipping...
# Processing Record 8 of Set 11 : norrtalje
# Processing Record 9 of Set 11 : ormara
# Processing Record 10 of Set 11 : klaksvik
# Processing Record 11 of Set 11 : terra santa
# Processing Record 12 of Set 11 : ulaanbaatar
# Processing Record 13 of Set 11 : olinda
# Processing Record 14 of Set 11 : kaeo
# Processing Record 15 of Set 11 : raga
# Processing Record 16 of Set 11 : hit
# Processing Record 17 of Set 11 : diffa
# Processing Record 18 of Set 11 : kerema
# Processing Record 19 of Set 11 : caxito
# Processing Record 20 of Set 11 : tiarei
# Processing Record 21 of Set 11 : luanda
# Processing Record 22 of Set 11 : beitbridge
# Processing Record 23 of Set 11 : jackson
# Processing Record 24 of Set 11 : ginda
# Processing Record 25 of Set 11 : agirish
# Processing Record 26 of Set 11 : itarema
# Processing Record 27 of Set 11 : deep river
# Processing Record 28 of Set 11 : seymchan
# Processing Record 29 of Set 11 : angoche
# Processing Record 30 of Set 11 : mirzapur
# Processing Record 31 of Set 11 : pucallpa
# Processing Record 32 of Set 11 : omsukchan
# Processing Record 33 of Set 11 : isangel
# Processing Record 34 of Set 11 : dire dawa
# Processing Record 35 of Set 11 : teguise
# Processing Record 36 of Set 11 : esso
# Processing Record 37 of Set 11 : dwarka
# Processing Record 38 of Set 11 : yarmouth
# Processing Record 39 of Set 11 : mnogovershinnyy
# Processing Record 40 of Set 11 : leshukonskoye
# Processing Record 41 of Set 11 : bar harbor
# Processing Record 42 of Set 11 : matara
# Processing Record 43 of Set 11 : kalmunai
# Processing Record 44 of Set 11 : fort nelson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
d = {"City": city_name, "Lat": lat, "Lng": lng, "Max Temp": max_temp, "Humidity": humidity, 
    "Cloudiness": cloudiness, "Wind Speed": windspeed, "Country":country, "Date": date}
df = pd.DataFrame(d)
df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Yārāda  17.6500   83.2667     30.14        66          70        2.92
# 1  New Norfolk -42.7826  147.0587     15.95        60          90        4.92
# 2    Cape Town -33.9258   18.4232     11.73        94           0        1.04
# 3    Bathsheba  13.2167  -59.5167     27.34        83          75        6.17
# 4        Pevek  69.7008  170.3133      4.12        93          94        3.10
#
#   Country        Date
# 0      IN  1628215647
# 1      AU  1628215606
# 2      ZA  1628215837
# 3      BB  1628215876
# 4      RU  1628215668

# %%
# Export to CSV 
df.to_csv("weather.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(df["Lat"], df["Max Temp"], edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.grid(linestyle="-", linewidth = 1, alpha = 0.5)
plt.savefig("City Lat vs Max Temp.png")
print(f"Analysis: The highest temperature is found at 40 latitude.")
# Out:
# Analysis: The highest temperature is found at 40 latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(df["Lat"], df["Humidity"], edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.grid(linestyle="-", linewidth = 1, alpha = 0.5)
plt.savefig("city_lat_vs_humidity.png")
print(f"Analysis: higher humidity is found between 0 and 20 latitude.")
# Out:
# Analysis: higher humidity is found between 0 and 20 latitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Lat"], df["Cloudiness"], edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.grid(linestyle="-", linewidth= 1, alpha = 0.5)
plt.savefig("city_lat_vs_cloudiness.png")
print(f"Analysis: cloudiness is widely spread across the latitude.")
# Out:
# Analysis: cloudiness is widely spread across the latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Lat"], df["Wind Speed"], edgecolor = "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (04/01/20)")
plt.grid(linestyle="-", linewidth= 1, alpha = 0.5)
plt.savefig("city_lat_vs_WindSpeed.png")
print(f"Analysis: as latitude increases, wind speed seems to decrease.")
# Out:
# Analysis: as latitude increases, wind speed seems to decrease.

# %% [markdown]
# ## Linear Regression

# %%
# Perform Linear Regression
def linear_reg(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
    print(f"The r-value is: {rvalue}")
    # Get regress values
    regress_values= x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    return line_eq
def annotate(line_eq, a, b):    
    plt.annotate(line_eq, (a,b), fontsize = 15, color = "red")
    
    
# Create Northern and Southern Hemisphere DataFrames
northern_hem = df.loc[df["Lat"] > 0]
southern_hem = df.loc[df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
eq = linear_reg(northern_hem["Lat"], northern_hem["Max Temp"])
annotate(eq, 0, 5)
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.savefig("north_MaxTemp_lat.png")

# There is a negative correlation between the Northern Hemisphere maximum temperature and latitude.
# Out:
# The r-value is: -0.6493955174072714

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
eq = linear_reg(southern_hem["Lat"], southern_hem["Max Temp"])
annotate(eq, -35,3)
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.savefig("south_MaxTemp_lat.png")

# Analysis: There is a positive linear relationship between the Southern Hemisphere maximum temperature and the latitude.
# Out:
# The r-value is: 0.7634819911569779

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
eq = linear_reg(northern_hem["Lat"], northern_hem["Humidity"])
annotate(eq, 45, 20)
plt.title("Northern Hemisphere -  Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("north_humidity_lat.png")

# Analysis: The two variables are not correlated.
# Out:
# The r-value is: -0.02735762819112851

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
eq = linear_reg(southern_hem["Lat"], southern_hem["Humidity"])
annotate(eq,0, 15)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("south_humidity_lat.png")

# Analysis: The two variables are not correlated.
# Out:
# The r-value is: -0.027900384136555195

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
eq = linear_reg(northern_hem["Lat"], northern_hem["Cloudiness"])
annotate(eq,80, 20)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("north_cloudiness_lat.png")

#Analysis: There is a negative correlation between the two variables.
# Out:
# The r-value is: -0.07777553987725626

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
eq = linear_reg(southern_hem["Lat"], southern_hem["Cloudiness"])
annotate(eq,0, 20)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("south_cloudiness_lat.png")

#Analysis: There is no correlation between the two variables.
# Out:
# The r-value is: 0.013222244202379439

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
eq = linear_reg(northern_hem["Lat"], northern_hem["Wind Speed"])
annotate(eq,40, 14)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("north_windspeed_lat.png")

#Analysis: There is no correlation between the two variables.
# Out:
# The r-value is: -0.06452912424039714

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
eq = linear_reg(southern_hem["Lat"], southern_hem["Wind Speed"])
annotate(eq,-50, 10)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("south_windspeed_lat.png")

#Analysis: There is more of a negative correlation between the two variables, than no correlation.
# Out:
# The r-value is: -0.20884387000969223
